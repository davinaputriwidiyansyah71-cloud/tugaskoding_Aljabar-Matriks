# %% [markdown]
# $No.1$

# %%
import numpy as np

# %%
x = np.array([19, 4, 7])
print(x)
# Out:
# [19  4  7]

# %%
y = np.array([0, 2, 4])
print(y)
# Out:
# [0 2 4]

# %%
import torch

# %%
# buat vector x_pt dan y_pt dengan ukuran 1x3 menggunakan pytorch
x_pt = torch.tensor([19, 4, 7])
print(x_pt)
# Out:
# tensor([19,  4,  7])

# %%
y_pt = torch.tensor([0, 2, 4])
print(y_pt)
# Out:
# tensor([0, 2, 4])

# %%
import tensorflow as tf

# %%
# buat vector x_tf dan y_tf dengan ukuran 1x3 menggunakan tensorflow
x_tf = tf.Variable([19, 4, 7])
print(x_tf)
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([19,  4,  7], dtype=int32)>

# %% [markdown]
# $No.2$

# %%
y_tf = tf.Variable([0, 2, 4])
print(y_tf)
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([0, 2, 4], dtype=int32)>

# %%
# hitung perkalian dot product antara vector x dan vector y
np.dot(x, y)
# Out:
# np.int64(36)

# %%
# hitung perkalian dot product antara vector x_pt dan vector y_pt
torch.dot(x_pt, y_pt)
# Out:
# tensor(36)

# %%
# hitung perkalian dot product antara vector x_tf dan vector y_tf
tf.reduce_sum(tf.multiply(x_tf, y_tf))
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=36>

# %% [markdown]
# $No.3$

# %%
# What is Y_Transpose?
Y = np.array([[42, 4, 7, 99],
              [-99, -3, 17, 22]])
Y_transpose
# Out:
# array([[ 42, -99],
#        [  4,  -3],
#        [  7,  17],
#        [ 99,  22]])

# %%
# What is The Hadamard product of these matrices?
A = np.array([[25, 10],
              [-2, 1]])

B = np.array([[-1, 7],
              [10, 8]])
A*B
# Out:
# array([[-25,  70],
#        [-20,   8]])

# %%
# What is the product of the tensor w and x?
w = np.array([-1, 2, -2])
x = np.array([5, 10, 0])
np.dot(w, x)
# Out:
# np.int64(15)
