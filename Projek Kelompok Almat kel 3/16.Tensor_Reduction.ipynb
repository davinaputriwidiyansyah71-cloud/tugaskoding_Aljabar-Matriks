# %% [markdown]
# soal no 1

# %%
import numpy as np
import torch
import tensorflow as tf

# %%
# buat matrix X dengan ukuran 2x3 menggunakan numpy
X = np.array([[20, 3, 7], [17, 6, 7]])
X
# Out:
# array([[20,  3,  7],
#        [17,  6,  7]])

# %%
# hitung berapa hasil penjumlahan elemen matrix X dengan fungsi sum
X.sum()
# Out:
# np.int64(60)

# %%
# buat matrix X_pt dengan ukuran 2x3 menggunakan pytorch
X_pt = torch.tensor([[20, 3, 7], [17, 6, 7]])
X_pt
# Out:
# tensor([[20,  3,  7],
#         [17,  6,  7]])

# %%
# buat matrix X_tf dengan ukuran 2x3 menggunakan tensorflow
X_tf = tf.Variable([[20, 3, 7], [17, 6, 7]])
X_tf
# Out:
# <tf.Variable 'Variable:0' shape=(2, 3) dtype=int32, numpy=
# array([[20,  3,  7],
#        [17,  6,  7]], dtype=int32)>

# %% [markdown]
# soal no 2

# %%
# hitung hasil penjumlahan seluruh elemen matrix X
X.sum()
# Out:
# np.int64(60)

# %%
# hitung hasil penjumlahan seluruh elemen matrix X_pt
torch.sum(X_pt)
# Out:
# tensor(60)

# %%
# hitung hasil penjumlahan seluruh elemen matrix X_tf
tf.reduce_sum(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=60>

# %% [markdown]
# soal no 3

# %%
# hitung hasil penjumlahan matrix X berdasarkan row nya
X.sum(axis=1)
# Out:
# array([30, 30])

# %%
# hitung hasil penjumlahan matrix X_pt berdasarkan row nya
torch.sum(X_pt, axis=1)
# Out:
# tensor([30, 30])

# %%
# hitung hasil penjumlahan matrix X_tf berdasarkan row nya
tf.reduce_sum(X_tf, axis=1)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([30, 30], dtype=int32)>

# %% [markdown]
# soal no 4

# %%
# hitung hasil penjumlahan matrix X berdasarkan kolom nya
X.sum(axis=0)
# Out:
# array([37,  9, 14])

# %%
# hitung hasil penjumlahan matrix X_pt berdasarkan kolom nya
torch.sum(X_pt, axis=0)
# Out:
# tensor([37,  9, 14])

# %%
# hitung hasil penjumlahan matrix X_tf berdasarkan kolom nya
tf.reduce_sum(X_tf, axis=1)
# Out:
# <tf.Tensor: shape=(2,), dtype=int32, numpy=array([30, 30], dtype=int32)>

# %% [markdown]
# soal no 5

# %%
# hitung nilai minimal dari matrix X
X.min()
# Out:
# np.int64(3)

# %%
# hitung nilai minimal dari matrix X_pt
X_pt.min()
# Out:
# tensor(3)

# %%
# hitung nilai minimal dari matrix X_tf
tf.reduce_min(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=3>

# %%
# hitung nilai maksimal dari matrix X
X.max()
# Out:
# np.int64(20)

# %%
# hitung nilai maksimal dari matrix X_pt
X_pt.max()
# Out:
# tensor(20)

# %%
# hitung nilai maksimal dari matrix X_tf
tf.reduce_max(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=20>

# %%
# hitung nilai rata-rata dari matrix X
X.mean()
# Out:
# np.float64(10.0)

# %%
# hitung nilai rata-rata dari matrix X_pt
X_pt.float().mean()
# Out:
# tensor(10.)

# %%
# hitung nilai rata-rata dari matrix X_tf
tf.reduce_mean(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=10>

# %% [markdown]
# soal no 6

# %%
# hitung hasil perkalian seluruh elemen matrix X
X.prod()
# Out:
# np.int64(299880)

# %%
# hitung hasil perkalian seluruh elemen matrix X_pt
X_pt.prod()
# Out:
# tensor(299880)

# %%
# hitung hasil perkalian seluruh elemen matrix X_tf
tf.reduce_prod(X_tf)
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=299880>
